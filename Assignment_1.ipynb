# %% [markdown]
# <a href="https://colab.research.google.com/github/AshaMariam/Assignment1/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 1 on Python for Data Science

# %% [markdown]
# Iris dataset

# %% [markdown]
# 1. Read the dataset to python environment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/iris.xls')
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Display the columns in the dataset

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
df.shape[1]
# Out:
# 5

# %% [markdown]
# 3. Calculate the mean of each column of the dataset.

# %%
df.mean()
# Out:
# <ipython-input-29-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
df.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.describe(include= 'all')
# Out:
#                 SL          SW          PL          PW Classification
# count   150.000000  150.000000  150.000000  150.000000            150
# unique         NaN         NaN         NaN         NaN              3
# top            NaN         NaN         NaN         NaN    Iris-setosa
# freq           NaN         NaN         NaN         NaN             50
# mean      5.843333    3.054000    3.758667    1.198667            NaN
# std       0.828066    0.433594    1.764420    0.763161            NaN
# min       4.300000    2.000000    1.000000    0.100000            NaN
# 25%       5.100000    2.800000    1.600000    0.300000            NaN
# 50%       5.800000    3.000000    4.350000    1.300000            NaN
# 75%       6.400000    3.300000    5.100000    1.800000            NaN
# max       7.900000    4.400000    6.900000    2.500000            NaN

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
df.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# 1. Boxplot

# %%
#SL vs Classification
sns.boxplot(x='SL',y='Classification',data=df)
plt.title('Sepal Length vs Classification')
plt.show()

# %%
#SW vs Classification
sns.boxplot(x='SW',y='Classification',data=df)
plt.title('Sepal Width vs Classification')
plt.show()

# %%
#PL vs Classification
sns.boxplot(x='PL',y='Classification',data=df)
plt.title('Petal Length vs Classification')
plt.show()

# %%
#PW vs Classification
sns.boxplot(x='PW',y='Classification',data=df)
plt.title('Petal Width vs Classification')
plt.show()

# %% [markdown]
# 2. Violin plot

# %%
#SL vs Classification
sns.violinplot(x='Classification', y='SL', data=df)
plt.title('Sepal Length by Classification')
plt.show()

# %%
#SW vs Classification
sns.violinplot(x='Classification', y='SW', data=df)
plt.title('Sepal Width by Classification')
plt.show()

# %%
#PL vs Classification
sns.violinplot(x='Classification', y='PL', data=df)
plt.title('Petal Length by Classification')
plt.show()

# %%
#PW vs Classification
sns.violinplot(x='Classification', y='PW', data=df)
plt.title('Petal Width by Classification')
plt.show()

# %% [markdown]
# 3. Barplot

# %%
#SL vs Classification
sns.barplot(x='Classification',y='SL',data=df)
plt.title('Sepal Length vs Classification')
plt.show()

# %%
#SW vs Classification
sns.barplot(x='Classification',y='SW',data=df)
plt.title('Sepal Width vs Classification')
plt.show()

# %%
#PL vs Classification
sns.barplot(x='Classification',y='PL',data=df)
plt.title('Petal Length vs Classification')
plt.show()

# %%
#PW vs Classification
sns.barplot(x='Classification',y='PW',data=df)
plt.title('Petal Width vs Classification')
plt.show()

# %% [markdown]
# 4. Scatter plot

# %%
sns.scatterplot(data=df, x="SL", y="SW", hue="Classification")
plt.title("Sepal Length vs Sepal Width")
plt.show()

# %%
sns.scatterplot(data=df, x="PL", y="PW", hue="Classification")
plt.title("Petal Length vs Petal Width")
plt.show()
